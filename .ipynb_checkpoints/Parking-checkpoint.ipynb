# %%
import pandas as pd

# %%
# df containging all zip
df = pd.read_csv("311_Service_Requests_2020.csv")
df.head()
# Out:
# /Users/eugenepaik/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# ...

# %%
# df2 is a subset of df, containing rows that include zip 10001
df2 = df[df["Incident Zip"] == 10001.0]
df2.head()
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 1506    45285919  01/01/2020 08:09:00 AM  01/01/2020 05:50:00 PM    DEP
# 1787    45288507  01/01/2020 10:01:28 AM  01/01/2020 10:11:54 AM    DHS
# 2355    45286809  01/01/2020 12:56:08 PM  01/01/2020 01:03:05 PM    DHS
# 2479    45285011  01/01/2020 01:29:18 PM  01/01/2020 02:54:52 PM   NYPD
# 2482    45288930  01/01/2020 01:30:35 PM                     NaN    TLC
#
#                                  Agency Name              Complaint Type  \
# 1506  Department of Environmental Protection                Water System
# 1787         Department of Homeless Services  Homeless Person Assistance
# 2355         Department of Homeless Services  Homeless Person Assistance
# 2479         New York City Police Department             Illegal Parking
# 2482           Taxi and Limousine Commission  For Hire Vehicle Complaint
#
#                             Descriptor    Location Type  Incident Zip  \
# ...

# %%
complaints = list(df2["Complaint Type"])
total_counts = 0
parking_counts = 0

for i in complaints:
    if i == "Illegal Parking":
        parking_counts += 1
    total_counts += 1 

print("total counts:", total_counts)
print("parking counts:", parking_counts)
# Out:
# total counts: 11617
# parking counts: 619

# %%
my_zip_proportion = (parking_counts / total_counts) * 100
print(my_zip_proportion)
# Out:
# 5.328398037359043

# %%
total_complaints = list(df["Complaint Type"])
total_zip_counts = 0
total_parking_counts = 0

for i in total_complaints:
    if i == "Illegal Parking":
        total_parking_counts += 1
    total_zip_counts += 1 

print("total zip counts:", total_zip_counts)
print("total parking counts:", total_parking_counts)
# Out:
# total zip counts: 2587316
# total parking counts: 193721

# %%
total_zip_proportion = (total_parking_counts / total_zip_counts) * 100
print(total_zip_proportion)
# Out:
# 7.4873343650331075

# %%
higher_parking_proportion = my_zip_proportion > total_zip_proportion
print(higher_parking_proportion)
# Out:
# False
